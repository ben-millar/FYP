# %% [markdown]
# ### 0. Helper functions

# %%
import numpy as np

class knapsack_data:
    def __init__(self, env):
        self.total_capacity = np.full(env.num_knapsacks, 0) # Total capacity seen across all trials
        self.capacity_used = np.full(env.num_knapsacks, 0) # Total capacity used across all trials
        
        self.placed = 0 # Number of items correctly placed
        self.misplaced = 0
        self.discarded = 0
        
        self.total_values = np.full(env.num_knapsacks, 0)
        self.min_value = 1_000_000
        self.max_value = -1
        
        self.steps_taken = 0 # Number of timesteps taken before trial terminated
        
        self.data_points = 0 # Number of trials we've witnessed
    

    def log(self, env):        
        self.total_capacity = np.add(self.total_capacity, env.num_knapsacks * env.capacity)
        #self.capacity_used = np.add(self.capacity_used, env.state[0][0])
        
        print(env.state)
        
        self.placed += env.logs["placed"]
        self.misplaced += env.logs["misplaced"]
        self.discarded += env.logs["discarded"]
        
        values = env.state[1][:-1]
        
        self.total_values += values
        self.max_value = max(self.max_value, max(values))
        self.min_value = min(self.min_value, min(values))
        
        self.steps_taken += sum(env.logs.values())
        
        self.data_points += 1
        

    def get_avg(self):
        percentages = self.capacity_used / self.total_capacity
        print(self.capacity_used)
        print(self.total_capacity)
        
        return {
            "steps" : self.steps_taken / self.data_points,
            "utilization" : sum(percentages) / len(percentages),
            "accuracy" : (self.placed / (self.placed + self.misplaced)) * 100,
            "min_value" : self.min_value,
            "max_value" : self.max_value,
            "avg_value" : sum(self.total_values) / (len(self.total_values) * self.data_points)
        }
    

    def print_data(self):
        data = self.get_avg()
        print(f'Average number of steps taken: {data["steps"]}')
        print(f'Average bin utilization: {round(data["utilization"], 2)}%')
        print(f'Accuracy: {round(data["accuracy"], 2)}%')
        print(f'Min value: {data["min_value"]}')
        print(f'Max value: {data["max_value"]}')
        print(f'Average value: {data["avg_value"]}')

# %% [markdown]
# ### 1. Import dependencies

# %%
# !pip install tensorflow==2.7.0
# !pip install gym
# !pip install keras
# !pip install keras-rl2

# %%
from KnapsackEnvironment1D import KnapsackPacking

# %% [markdown]
# ### 2. Create environment

# %%
env = KnapsackPacking(num_knapsacks=10, capacity=20)

# %%
env.action_space.sample()
# Out:
# 0

# %%
env.observation_space.sample()
# Out:
# array([[  13,   15,   16,    0,   19,    8,   17,   14,   20,   12,    9],
#        [ 107, 1831,  165,  655, 1184,  341, 1430, 1569,  710, 1141,  689]])

# %% [markdown]
# ### 3. Run baseline test (No ML)

# %%
control_data = knapsack_data(env)

# %%
MAX_STEPS = 1000
episodes = 10

for episode in range(1, episodes+1):
    state = env.reset()
    steps = 0
    done = False
    score = 0
    
    while not done and steps < MAX_STEPS:
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
        steps += 1

    print('Episode:{} Score:{}'.format(episode,score))
    print(env.logs)
    control_data.log(env)
    env.logs = { 'placed':0, 'misplaced':0, 'discarded':0 }
# Out:
# Episode:1 Score:-913
# {'placed': 134, 'misplaced': 783, 'discarded': 83}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-501f5bb63152> in <module>
#      16     print('Episode:{} Score:{}'.format(episode,score))
#      17     print(env.logs)
# ---> 18     control_data.log(env)
#      19     env.logs = { 'placed':0, 'misplaced':0, 'discarded':0 }
#
# <ipython-input-28-0b873cf4d0ae> in log(self, env)
#      21     def log(self, env):
#      22         self.total_capacity = np.add(self.total_capacity, env.num_knapsacks * env.capacity)
# ---> 23         self.capacity_used = np.add(self.capacity_used, env.state[0:-1][0])
#      24
#      25         self.placed += env.logs["placed"]
#
# ValueError: operands could not be broadcast together with shapes (10,) (11,)

# %%
control_data.print_data()
# Out:
# [  0 200   0   0   0   0   0   0   0   0]
# [2000 2000 2000 2000 2000 2000 2000 2000 2000 2000]
# Average number of steps taken: 1000.0
# Average bin utilization: 0.01%
# Accuracy: 15.12%
# Min value: 0
# Max value: 555
# Average value: 215.76

# %% [markdown]
# ### 4. Train an RL Model

# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
# Will throw an error if these don't exist
log_path = os.path.join('Training', 'Logs')

# %%
env = KnapsackPacking(num_knapsacks=10, capacity=20)

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=80000)
# Out:
# Logging to Training\Logs\PPO_54
# -----------------------------
# | time/              |      |
# |    fps             | 276  |
# |    iterations      | 1    |
# |    time_elapsed    | 7    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 397        |
# |    iterations           | 2          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.02025288 |
# |    clip_fraction        | 0.55       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.676     |
# |    explained_variance   | 0.00212    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.33e+03   |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0501    |
# |    value_loss           | 7.29e+03   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 458        |
# |    iterations           | 3          |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.02894373 |
# |    clip_fraction        | 0.44       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.603     |
# |    explained_variance   | 2.56e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.28e+03   |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0523    |
# |    value_loss           | 4.86e+03   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 499        |
# |    iterations           | 4          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.06048905 |
# |    clip_fraction        | 0.326      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.443     |
# |    explained_variance   | -4.77e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.29e+03   |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0432    |
# |    value_loss           | 2.9e+03    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 530        |
# |    iterations           | 5          |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.12489022 |
# |    clip_fraction        | 0.152      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.204     |
# |    explained_variance   | -3.58e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 523        |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0316    |
# |    value_loss           | 1.17e+03   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 551         |
# |    iterations           | 6           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.017065106 |
# |    clip_fraction        | 0.0326      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0688     |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.1        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 203         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 568          |
# |    iterations           | 7            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0016213811 |
# |    clip_fraction        | 0.0062       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0295      |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.2         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00475     |
# |    value_loss           | 76.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 8            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0013653244 |
# |    clip_fraction        | 0.00522      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0141      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.47         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00434     |
# |    value_loss           | 56.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 587          |
# |    iterations           | 9            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 8.717997e-05 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00782     |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.28         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000621    |
# |    value_loss           | 31.4         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 589           |
# |    iterations           | 10            |
# |    time_elapsed         | 34            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.00010279872 |
# |    clip_fraction        | 0.000928      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00485      |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.12          |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.00116      |
# |    value_loss           | 22.5          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 595           |
# |    iterations           | 11            |
# |    time_elapsed         | 37            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.00026188255 |
# |    clip_fraction        | 0.00142       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00268      |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.502         |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.00165      |
# |    value_loss           | 15.4          |
# -------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 600       |
# |    iterations           | 12        |
# |    time_elapsed         | 40        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0026   |
# |    explained_variance   | 5.36e-07  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00223   |
# |    n_updates            | 110       |
# |    policy_gradient_loss | -4.65e-06 |
# |    value_loss           | 7.51      |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 599          |
# |    iterations           | 13           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0003433791 |
# |    clip_fraction        | 0.000928     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00126     |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.276        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 6            |
# ------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 604       |
# |    iterations           | 14        |
# |    time_elapsed         | 47        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00108  |
# |    explained_variance   | -3.58e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000384  |
# |    n_updates            | 130       |
# |    policy_gradient_loss | 1.42e-05  |
# |    value_loss           | 2.87      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 603       |
# |    iterations           | 15        |
# |    time_elapsed         | 50        |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00108  |
# |    explained_variance   | -3.58e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00146   |
# |    n_updates            | 140       |
# |    policy_gradient_loss | -1.76e-05 |
# |    value_loss           | 1.56      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 606       |
# |    iterations           | 16        |
# |    time_elapsed         | 54        |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00109  |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000539  |
# |    n_updates            | 150       |
# |    policy_gradient_loss | 0.00261   |
# |    value_loss           | 0.895     |
# ---------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 610      |
# |    iterations           | 17       |
# |    time_elapsed         | 57       |
# |    total_timesteps      | 34816    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00117 |
# |    explained_variance   | 1.19e-07 |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0296   |
# |    n_updates            | 160      |
# |    policy_gradient_loss | 0.00239  |
# |    value_loss           | 0.523    |
# --------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 608       |
# |    iterations           | 18        |
# |    time_elapsed         | 60        |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00123  |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 6.96e-05  |
# |    n_updates            | 170       |
# |    policy_gradient_loss | -0.000178 |
# |    value_loss           | 0.298     |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 606       |
# |    iterations           | 19        |
# |    time_elapsed         | 64        |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00123  |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00231   |
# |    n_updates            | 180       |
# |    policy_gradient_loss | 2.46e-05  |
# |    value_loss           | 0.17      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 606       |
# |    iterations           | 20        |
# |    time_elapsed         | 67        |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00125  |
# |    explained_variance   | -2.38e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.84e-05  |
# |    n_updates            | 190       |
# |    policy_gradient_loss | 0.00085   |
# |    value_loss           | 0.0981    |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 603       |
# |    iterations           | 21        |
# |    time_elapsed         | 71        |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00127  |
# |    explained_variance   | -1.67e-06 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00734   |
# |    n_updates            | 200       |
# |    policy_gradient_loss | 1.05e-05  |
# |    value_loss           | 0.0579    |
# ---------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 599      |
# |    iterations           | 22       |
# |    time_elapsed         | 75       |
# |    total_timesteps      | 45056    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00127 |
# |    explained_variance   | 7.15e-07 |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.000281 |
# |    n_updates            | 210      |
# |    policy_gradient_loss | -0.00017 |
# |    value_loss           | 0.0351   |
# --------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 599           |
# |    iterations           | 23            |
# |    time_elapsed         | 78            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00042377174 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000384     |
# |    explained_variance   | -4.77e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00929       |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000651     |
# |    value_loss           | 0.366         |
# -------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 601       |
# |    iterations           | 24        |
# |    time_elapsed         | 81        |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000274 |
# |    explained_variance   | 1.79e-07  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.29e-05  |
# |    n_updates            | 230       |
# |    policy_gradient_loss | 2.11e-05  |
# |    value_loss           | 0.0146    |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 602       |
# |    iterations           | 25        |
# |    time_elapsed         | 84        |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000274 |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.38e-06  |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -7.34e-05 |
# |    value_loss           | 0.00826   |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 603       |
# |    iterations           | 26        |
# |    time_elapsed         | 88        |
# |    total_timesteps      | 53248     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000274 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 6.67e-05  |
# |    n_updates            | 250       |
# |    policy_gradient_loss | 2.11e-05  |
# |    value_loss           | 0.00503   |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 602       |
# |    iterations           | 27        |
# |    time_elapsed         | 91        |
# |    total_timesteps      | 55296     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000274 |
# |    explained_variance   | -3.22e-06 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00025   |
# |    n_updates            | 260       |
# |    policy_gradient_loss | 4.67e-05  |
# |    value_loss           | 0.0031    |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 604       |
# |    iterations           | 28        |
# |    time_elapsed         | 94        |
# |    total_timesteps      | 57344     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000274 |
# |    explained_variance   | 4.17e-07  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.76e-05  |
# |    n_updates            | 270       |
# |    policy_gradient_loss | 0.000129  |
# |    value_loss           | 0.00195   |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 606       |
# |    iterations           | 29        |
# |    time_elapsed         | 97        |
# |    total_timesteps      | 59392     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000274 |
# |    explained_variance   | 1.79e-07  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000302  |
# |    n_updates            | 280       |
# |    policy_gradient_loss | 2.94e-05  |
# |    value_loss           | 0.00125   |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 607       |
# |    iterations           | 30        |
# |    time_elapsed         | 101       |
# |    total_timesteps      | 61440     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000274 |
# |    explained_variance   | -2.15e-06 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000401  |
# |    n_updates            | 290       |
# |    policy_gradient_loss | 6.13e-05  |
# |    value_loss           | 0.000826  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 607       |
# |    iterations           | 31        |
# |    time_elapsed         | 104       |
# |    total_timesteps      | 63488     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000274 |
# |    explained_variance   | 3.93e-06  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.48e-05  |
# |    n_updates            | 300       |
# |    policy_gradient_loss | 6.11e-06  |
# |    value_loss           | 0.00054   |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 604       |
# |    iterations           | 32        |
# |    time_elapsed         | 108       |
# |    total_timesteps      | 65536     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000274 |
# |    explained_variance   | 3.58e-07  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.49e-05  |
# |    n_updates            | 310       |
# |    policy_gradient_loss | -0.000484 |
# |    value_loss           | 0.000363  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 601       |
# |    iterations           | 33        |
# |    time_elapsed         | 112       |
# |    total_timesteps      | 67584     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000274 |
# |    explained_variance   | 5.96e-07  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.13e-06  |
# |    n_updates            | 320       |
# |    policy_gradient_loss | -0.000471 |
# |    value_loss           | 0.000245  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 601       |
# |    iterations           | 34        |
# |    time_elapsed         | 115       |
# |    total_timesteps      | 69632     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000274 |
# |    explained_variance   | 2.21e-06  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.06e-05  |
# |    n_updates            | 330       |
# |    policy_gradient_loss | -5.6e-06  |
# |    value_loss           | 0.000169  |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 601          |
# |    iterations           | 35           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0003134342 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.79e-05    |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000986     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000659    |
# |    value_loss           | 0.339        |
# ------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 601       |
# |    iterations           | 36        |
# |    time_elapsed         | 122       |
# |    total_timesteps      | 73728     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.61e-05 |
# |    explained_variance   | 6.5e-06   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.85e-06  |
# |    n_updates            | 350       |
# |    policy_gradient_loss | 1.01e-05  |
# |    value_loss           | 6.2e-05   |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 602       |
# |    iterations           | 37        |
# |    time_elapsed         | 125       |
# |    total_timesteps      | 75776     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.61e-05 |
# |    explained_variance   | 2.26e-05  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.86e-05  |
# |    n_updates            | 360       |
# |    policy_gradient_loss | 2.25e-05  |
# |    value_loss           | 4.44e-05  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 602       |
# |    iterations           | 38        |
# |    time_elapsed         | 129       |
# |    total_timesteps      | 77824     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.61e-05 |
# |    explained_variance   | -7.39e-06 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.44e-06  |
# |    n_updates            | 370       |
# |    policy_gradient_loss | 5.32e-06  |
# |    value_loss           | 3.03e-05  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 603       |
# |    iterations           | 39        |
# |    time_elapsed         | 132       |
# |    total_timesteps      | 79872     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.61e-05 |
# |    explained_variance   | 3.24e-05  |
# |    learning_rate        | 0.0003    |
# |    loss                 | -1.29e-07 |
# |    n_updates            | 380       |
# |    policy_gradient_loss | 0.000588  |
# |    value_loss           | 2.07e-05  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 601       |
# |    iterations           | 40        |
# |    time_elapsed         | 136       |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.61e-05 |
# |    explained_variance   | 9.5e-05   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.29e-07  |
# |    n_updates            | 390       |
# |    policy_gradient_loss | -3.24e-05 |
# |    value_loss           | 1.43e-05  |
# ---------------------------------------

# %% [markdown]
# ### 5. Save model

# %%
#PPO_Path = os.path.join('Training', 'Saved Models', 'Constant_PPO_Model_Discard_Penalty')

# %%
#model.save(PPO_Path)

# %% [markdown]
# ### 6. Load model

# %%
#model = PPO.load(PPO_Path, env=env)

# %% [markdown]
# ### 7. Test model

# %%
real_data = knapsack_data(env)
env.logs = { 'placed':0, 'misplaced':0, 'discarded':0 }

# %%
MAX_STEPS = 1000
episodes = 10

for episode in range(1, episodes+1):
    obs = env.reset()
    steps = 0
    done = False
    score = 0
    
    while not done and steps < MAX_STEPS:
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score += reward
        steps += 1

    print('Episode:{} Score:{}'.format(episode,score))
    print(env.logs)
    real_data.log(env)
    env.logs = { 'placed':0, 'misplaced':0, 'discarded':0 }
# Out:
# Episode:1 Score:-892
# {'placed': 2, 'misplaced': 0, 'discarded': 998}
# Episode:2 Score:-906
# {'placed': 1, 'misplaced': 0, 'discarded': 999}
# Episode:3 Score:-928
# {'placed': 1, 'misplaced': 0, 'discarded': 999}
# Episode:4 Score:-860
# {'placed': 2, 'misplaced': 1, 'discarded': 997}
# Episode:5 Score:-887
# {'placed': 2, 'misplaced': 0, 'discarded': 998}
# Episode:6 Score:-925
# {'placed': 1, 'misplaced': 0, 'discarded': 999}
# Episode:7 Score:-853
# {'placed': 2, 'misplaced': 0, 'discarded': 998}
# Episode:8 Score:-906
# {'placed': 1, 'misplaced': 0, 'discarded': 999}
# Episode:9 Score:-835
# {'placed': 2, 'misplaced': 0, 'discarded': 998}
# Episode:10 Score:-868
# {'placed': 2, 'misplaced': 0, 'discarded': 998}

# %%
control_data.print_data()
# Out:
# Average number of steps taken: 1000.0
# Average bin utilization: 0.09%
# Accuracy: 0.87%
# Min value: 0
# Max value: 350
# Average value: 22.59

# %%
real_data.print_data()
# Out:
# Average number of steps taken: 1000.0
# Average bin utilization: 6.5%
# Accuracy: 96.97%
# Min value: 0
# Max value: 173
# Average value: 11.48

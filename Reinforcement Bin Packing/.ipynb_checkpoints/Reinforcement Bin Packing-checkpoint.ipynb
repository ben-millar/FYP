# %% [markdown]
# ### 0. Helper functions

# %%
def get_percentage_filled(env):
    percentages = 100 - ((env.state/env.capacity) * 100)
    for i in range(10):
        print(f"Bin {i+1}: {percentages[i]}%")
        
def print_metrics(env):

# %% [markdown]
# ### 1. Import dependencies

# %%
# !pip install tensorflow==2.7.0
# !pip install gym
# !pip install keras
# !pip install keras-rl2

# %%
from BinPackingEnvironment1D import BinPacking

# %% [markdown]
# ### 2. Create environment

# %%
env = BinPacking(num_bins=10, capacity=20, min_item_size=1)

# %%
env.action_space.sample()
# Out:
# 0

# %%
env.observation_space.sample()
# Out:
# array([20, 10, 15,  0, 17,  6,  6,  9, 20,  9, 11])

# %% [markdown]
# ### 3. Run baseline test (No ML)

# %%
MAX_STEPS = 1000
episodes = 10

for episode in range(1, episodes+1):
    state = env.reset()
    steps = 0
    done = False
    score = 0
    
    while not done and steps < MAX_STEPS:
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
        steps += 1

    print('Episode:{} Score:{}'.format(episode,score))
    print_metrics(env)
    env.logs = { 'placed':0, 'misplaced':0, 'discarded':0 }
# Out:
# Episode:1 Score:-280
# {'placed': 46, 'misplaced': 326, 'discarded': 47}
# Total timesteps: 419
# Bin 1: 95.0%
# Bin 2: 95.0%
# Bin 3: 100.0%
# Bin 4: 100.0%
# Bin 5: 100.0%
# Bin 6: 100.0%
# Bin 7: 100.0%
# Bin 8: 100.0%
# Bin 9: 95.0%
# Bin 10: 100.0%
# None
# Episode:2 Score:-131
# {'placed': 48, 'misplaced': 179, 'discarded': 25}
# Total timesteps: 252
# Bin 1: 100.0%
# Bin 2: 100.0%
# Bin 3: 100.0%
# Bin 4: 100.0%
# Bin 5: 95.0%
# Bin 6: 100.0%
# Bin 7: 100.0%
# Bin 8: 100.0%
# Bin 9: 100.0%
# Bin 10: 100.0%
# None
# Episode:3 Score:-89
# {'placed': 44, 'misplaced': 133, 'discarded': 25}
# Total timesteps: 202
# Bin 1: 100.0%
# Bin 2: 100.0%
# Bin 3: 100.0%
# Bin 4: 95.0%
# Bin 5: 100.0%
# Bin 6: 100.0%
# Bin 7: 100.0%
# Bin 8: 95.0%
# Bin 9: 95.0%
# Bin 10: 100.0%
# None
# Episode:4 Score:-373
# {'placed': 43, 'misplaced': 416, 'discarded': 58}
# Total timesteps: 517
# Bin 1: 95.0%
# Bin 2: 100.0%
# Bin 3: 100.0%
# Bin 4: 100.0%
# Bin 5: 100.0%
# Bin 6: 100.0%
# Bin 7: 100.0%
# Bin 8: 95.0%
# Bin 9: 95.0%
# Bin 10: 100.0%
# None
# Episode:5 Score:-166
# {'placed': 49, 'misplaced': 215, 'discarded': 19}
# Total timesteps: 283
# Bin 1: 100.0%
# Bin 2: 100.0%
# Bin 3: 100.0%
# Bin 4: 100.0%
# Bin 5: 100.0%
# Bin 6: 100.0%
# Bin 7: 100.0%
# Bin 8: 100.0%
# Bin 9: 95.0%
# Bin 10: 100.0%
# None
# Episode:6 Score:-93
# {'placed': 43, 'misplaced': 136, 'discarded': 19}
# Total timesteps: 198
# Bin 1: 95.0%
# Bin 2: 100.0%
# Bin 3: 95.0%
# Bin 4: 100.0%
# Bin 5: 95.0%
# Bin 6: 100.0%
# Bin 7: 100.0%
# Bin 8: 100.0%
# Bin 9: 95.0%
# Bin 10: 95.0%
# None
# Episode:7 Score:-313
# {'placed': 50, 'misplaced': 363, 'discarded': 40}
# Total timesteps: 453
# Bin 1: 100.0%
# Bin 2: 100.0%
# Bin 3: 100.0%
# Bin 4: 100.0%
# Bin 5: 100.0%
# Bin 6: 100.0%
# Bin 7: 100.0%
# Bin 8: 100.0%
# Bin 9: 95.0%
# Bin 10: 95.0%
# None
# Episode:8 Score:-370
# {'placed': 42, 'misplaced': 412, 'discarded': 37}
# Total timesteps: 491
# Bin 1: 95.0%
# Bin 2: 100.0%
# Bin 3: 100.0%
# Bin 4: 95.0%
# Bin 5: 100.0%
# Bin 6: 100.0%
# Bin 7: 95.0%
# Bin 8: 100.0%
# Bin 9: 95.0%
# Bin 10: 100.0%
# None
# Episode:9 Score:-486
# {'placed': 41, 'misplaced': 527, 'discarded': 55}
# Total timesteps: 623
# Bin 1: 95.0%
# Bin 2: 95.0%
# Bin 3: 95.0%
# Bin 4: 100.0%
# Bin 5: 95.0%
# Bin 6: 100.0%
# Bin 7: 100.0%
# Bin 8: 95.0%
# Bin 9: 95.0%
# Bin 10: 95.0%
# None
# Episode:10 Score:-395
# {'placed': 43, 'misplaced': 438, 'discarded': 46}
# Total timesteps: 527
# Bin 1: 100.0%
# Bin 2: 100.0%
# Bin 3: 100.0%
# Bin 4: 95.0%
# Bin 5: 95.0%
# Bin 6: 95.0%
# Bin 7: 95.0%
# Bin 8: 95.0%
# Bin 9: 100.0%
# Bin 10: 95.0%
# None

# %% [markdown]
# ### 4. Train an RL Model

# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
# Will throw an error if these don't exist
log_path = os.path.join('Training', 'Logs')

# %%
env = BinPacking(num_bins=10, capacity=20, min_item_size=1)

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=200000)
# Out:
# Logging to Training\Logs\PPO_37
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 168      |
# |    ep_rew_mean     | 52.3     |
# | time/              |          |
# |    fps             | 2207     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 177         |
# |    ep_rew_mean          | 52.5        |
# | time/                   |             |
# |    fps                  | 1527        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008030068 |
# |    clip_fraction        | 0.0974      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.673       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0254     |
# |    value_loss           | 1.7         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 187         |
# |    ep_rew_mean          | 54.2        |
# | time/                   |             |
# |    fps                  | 1403        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008273931 |
# |    clip_fraction        | 0.097       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.914      |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.596       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0256     |
# |    value_loss           | 1.53        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 182         |
# |    ep_rew_mean          | 53.9        |
# | time/                   |             |
# |    fps                  | 1347        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008945228 |
# |    clip_fraction        | 0.091       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.871      |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.279       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0238     |
# |    value_loss           | 1.33        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 54.1         |
# | time/                   |              |
# |    fps                  | 1296         |
# |    iterations           | 5            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0090494435 |
# |    clip_fraction        | 0.0966       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.908       |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.486        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0261      |
# |    value_loss           | 1.46         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 55.3        |
# | time/                   |             |
# |    fps                  | 1256        |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010938169 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.865      |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.336       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0267     |
# |    value_loss           | 0.964       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 182         |
# |    ep_rew_mean          | 55.8        |
# | time/                   |             |
# |    fps                  | 1238        |
# |    iterations           | 7           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008983104 |
# |    clip_fraction        | 0.0932      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.842      |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.488       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.022      |
# |    value_loss           | 1.21        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 183        |
# |    ep_rew_mean          | 56.1       |
# | time/                   |            |
# |    fps                  | 1215       |
# |    iterations           | 8          |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00866503 |
# |    clip_fraction        | 0.0819     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.728     |
# |    explained_variance   | 0.986      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.343      |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0214    |
# |    value_loss           | 0.753      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 185         |
# |    ep_rew_mean          | 56.8        |
# | time/                   |             |
# |    fps                  | 1204        |
# |    iterations           | 9           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009149464 |
# |    clip_fraction        | 0.0866      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.732      |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.332       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0228     |
# |    value_loss           | 0.806       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 188          |
# |    ep_rew_mean          | 57.8         |
# | time/                   |              |
# |    fps                  | 1189         |
# |    iterations           | 10           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0088745095 |
# |    clip_fraction        | 0.0958       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.719       |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.299        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.023       |
# |    value_loss           | 0.714        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 190         |
# |    ep_rew_mean          | 59.3        |
# | time/                   |             |
# |    fps                  | 1178        |
# |    iterations           | 11          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008239522 |
# |    clip_fraction        | 0.0867      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.734      |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.188       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0186     |
# |    value_loss           | 0.777       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | 60.3        |
# | time/                   |             |
# |    fps                  | 1176        |
# |    iterations           | 12          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009736506 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.76       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.182       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0231     |
# |    value_loss           | 0.723       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 195        |
# |    ep_rew_mean          | 60.8       |
# | time/                   |            |
# |    fps                  | 1161       |
# |    iterations           | 13         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.00903853 |
# |    clip_fraction        | 0.0857     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.641     |
# |    explained_variance   | 0.99       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.249      |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0186    |
# |    value_loss           | 0.6        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | 61.7        |
# | time/                   |             |
# |    fps                  | 1159        |
# |    iterations           | 14          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011029121 |
# |    clip_fraction        | 0.0833      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.647      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.207       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0216     |
# |    value_loss           | 0.565       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 203         |
# |    ep_rew_mean          | 62.7        |
# | time/                   |             |
# |    fps                  | 1151        |
# |    iterations           | 15          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007000787 |
# |    clip_fraction        | 0.0746      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.171       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0201     |
# |    value_loss           | 0.594       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 207         |
# |    ep_rew_mean          | 63.1        |
# | time/                   |             |
# |    fps                  | 1153        |
# |    iterations           | 16          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011529959 |
# |    clip_fraction        | 0.085       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.619      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.116       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0187     |
# |    value_loss           | 0.379       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 213         |
# |    ep_rew_mean          | 64.1        |
# | time/                   |             |
# |    fps                  | 1154        |
# |    iterations           | 17          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009182863 |
# |    clip_fraction        | 0.0873      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.617      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.18        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 0.466       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 213         |
# |    ep_rew_mean          | 64.6        |
# | time/                   |             |
# |    fps                  | 1158        |
# |    iterations           | 18          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008084428 |
# |    clip_fraction        | 0.0796      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.562      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.174       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 0.405       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 217         |
# |    ep_rew_mean          | 65.6        |
# | time/                   |             |
# |    fps                  | 1157        |
# |    iterations           | 19          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007313433 |
# |    clip_fraction        | 0.0818      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.619      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.161       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 0.49        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 218         |
# |    ep_rew_mean          | 66          |
# | time/                   |             |
# |    fps                  | 1156        |
# |    iterations           | 20          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008594396 |
# |    clip_fraction        | 0.0695      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.606      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.168       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 0.502       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 217        |
# |    ep_rew_mean          | 65.8       |
# | time/                   |            |
# |    fps                  | 1155       |
# |    iterations           | 21         |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01049688 |
# |    clip_fraction        | 0.082      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.606     |
# |    explained_variance   | 0.995      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.195      |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.016     |
# |    value_loss           | 0.433      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 217         |
# |    ep_rew_mean          | 65.6        |
# | time/                   |             |
# |    fps                  | 1153        |
# |    iterations           | 22          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010317618 |
# |    clip_fraction        | 0.0813      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.661      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.149       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 0.459       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 214         |
# |    ep_rew_mean          | 65.5        |
# | time/                   |             |
# |    fps                  | 1152        |
# |    iterations           | 23          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009514764 |
# |    clip_fraction        | 0.0757      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.601      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.135       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 0.575       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 214          |
# |    ep_rew_mean          | 65.7         |
# | time/                   |              |
# |    fps                  | 1152         |
# |    iterations           | 24           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0072709923 |
# |    clip_fraction        | 0.075        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.578       |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.151        |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0195      |
# |    value_loss           | 0.465        |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 213       |
# |    ep_rew_mean          | 65.5      |
# | time/                   |           |
# |    fps                  | 1152      |
# |    iterations           | 25        |
# |    time_elapsed         | 44        |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0082056 |
# |    clip_fraction        | 0.0809    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.645    |
# |    explained_variance   | 0.993     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.257     |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.0165   |
# |    value_loss           | 0.549     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 212         |
# |    ep_rew_mean          | 65.3        |
# | time/                   |             |
# |    fps                  | 1152        |
# |    iterations           | 26          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008859813 |
# |    clip_fraction        | 0.0879      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.591      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.105       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 0.396       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 209         |
# |    ep_rew_mean          | 65.1        |
# | time/                   |             |
# |    fps                  | 1153        |
# |    iterations           | 27          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007885426 |
# |    clip_fraction        | 0.0799      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.212       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0175     |
# |    value_loss           | 0.479       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 210         |
# |    ep_rew_mean          | 65          |
# | time/                   |             |
# |    fps                  | 1155        |
# |    iterations           | 28          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009087045 |
# |    clip_fraction        | 0.0806      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.57       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.104       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 0.473       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 211         |
# |    ep_rew_mean          | 64.9        |
# | time/                   |             |
# |    fps                  | 1155        |
# |    iterations           | 29          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.007141566 |
# |    clip_fraction        | 0.0867      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.559      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.13        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0174     |
# |    value_loss           | 0.434       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 214         |
# |    ep_rew_mean          | 64.8        |
# | time/                   |             |
# |    fps                  | 1156        |
# |    iterations           | 30          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.013456427 |
# |    clip_fraction        | 0.0846      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.535      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.131       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 0.447       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 215         |
# |    ep_rew_mean          | 64.8        |
# | time/                   |             |
# |    fps                  | 1157        |
# |    iterations           | 31          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.008685157 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.474      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.141       |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 0.375       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 217         |
# |    ep_rew_mean          | 64.9        |
# | time/                   |             |
# |    fps                  | 1158        |
# |    iterations           | 32          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009108453 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.539      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.188       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 0.446       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 219         |
# |    ep_rew_mean          | 64.8        |
# | time/                   |             |
# |    fps                  | 1156        |
# |    iterations           | 33          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.011621784 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.51       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.155       |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0207     |
# |    value_loss           | 0.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 222         |
# |    ep_rew_mean          | 65          |
# | time/                   |             |
# |    fps                  | 1157        |
# |    iterations           | 34          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.009561116 |
# |    clip_fraction        | 0.0774      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.465      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.218       |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0155     |
# |    value_loss           | 0.336       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 225         |
# |    ep_rew_mean          | 65.1        |
# | time/                   |             |
# |    fps                  | 1158        |
# |    iterations           | 35          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.008931698 |
# |    clip_fraction        | 0.0845      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.475      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.185       |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 0.418       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 229         |
# |    ep_rew_mean          | 65.8        |
# | time/                   |             |
# |    fps                  | 1157        |
# |    iterations           | 36          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.007610181 |
# |    clip_fraction        | 0.0685      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.45       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.115       |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 0.348       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 234         |
# |    ep_rew_mean          | 66          |
# | time/                   |             |
# |    fps                  | 1156        |
# |    iterations           | 37          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.010445885 |
# |    clip_fraction        | 0.0838      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.504      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.103       |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 0.417       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 66.5        |
# | time/                   |             |
# |    fps                  | 1156        |
# |    iterations           | 38          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.011909971 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.412      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0944      |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 0.267       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 238         |
# |    ep_rew_mean          | 66.6        |
# | time/                   |             |
# |    fps                  | 1155        |
# |    iterations           | 39          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.009905898 |
# |    clip_fraction        | 0.0793      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.443      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0955      |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 0.37        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 241         |
# |    ep_rew_mean          | 66.8        |
# | time/                   |             |
# |    fps                  | 1154        |
# |    iterations           | 40          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008391905 |
# |    clip_fraction        | 0.0785      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.488      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.101       |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 0.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 241         |
# |    ep_rew_mean          | 66.8        |
# | time/                   |             |
# |    fps                  | 1154        |
# |    iterations           | 41          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.009922081 |
# |    clip_fraction        | 0.0895      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.448      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.147       |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 0.328       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 241       |
# |    ep_rew_mean          | 67.1      |
# | time/                   |           |
# |    fps                  | 1155      |
# |    iterations           | 42        |
# |    time_elapsed         | 74        |
# |    total_timesteps      | 86016     |
# | train/                  |           |
# |    approx_kl            | 0.0103937 |
# |    clip_fraction        | 0.087     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.462    |
# |    explained_variance   | 0.994     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0891    |
# |    n_updates            | 610       |
# |    policy_gradient_loss | -0.0149   |
# |    value_loss           | 0.358     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 245         |
# |    ep_rew_mean          | 67.7        |
# | time/                   |             |
# |    fps                  | 1154        |
# |    iterations           | 43          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.009613574 |
# |    clip_fraction        | 0.0903      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.456      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.25        |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 0.44        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 249          |
# |    ep_rew_mean          | 67.9         |
# | time/                   |              |
# |    fps                  | 1155         |
# |    iterations           | 44           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0108583905 |
# |    clip_fraction        | 0.0781       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.446       |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.141        |
# |    n_updates            | 630          |
# |    policy_gradient_loss | -0.0128      |
# |    value_loss           | 0.409        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 250         |
# |    ep_rew_mean          | 68.9        |
# | time/                   |             |
# |    fps                  | 1154        |
# |    iterations           | 45          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.011908356 |
# |    clip_fraction        | 0.0908      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.412      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.137       |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 0.393       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 249        |
# |    ep_rew_mean          | 69.5       |
# | time/                   |            |
# |    fps                  | 1155       |
# |    iterations           | 46         |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.01083586 |
# |    clip_fraction        | 0.0927     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.517     |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.148      |
# |    n_updates            | 650        |
# |    policy_gradient_loss | -0.0167    |
# |    value_loss           | 0.449      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 253         |
# |    ep_rew_mean          | 70.1        |
# | time/                   |             |
# |    fps                  | 1153        |
# |    iterations           | 47          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.009271375 |
# |    clip_fraction        | 0.0824      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.493      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.14        |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 0.484       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 253         |
# |    ep_rew_mean          | 70.3        |
# | time/                   |             |
# |    fps                  | 1153        |
# |    iterations           | 48          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009401528 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.454      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0938      |
# |    n_updates            | 670         |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 0.292       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 250         |
# |    ep_rew_mean          | 70.7        |
# | time/                   |             |
# |    fps                  | 1152        |
# |    iterations           | 49          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.010284346 |
# |    clip_fraction        | 0.0842      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.461      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.144       |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 0.399       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 250         |
# |    ep_rew_mean          | 71          |
# | time/                   |             |
# |    fps                  | 1153        |
# |    iterations           | 50          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.012570868 |
# |    clip_fraction        | 0.0967      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.484      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0733      |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.0187     |
# |    value_loss           | 0.321       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 252         |
# |    ep_rew_mean          | 71.5        |
# | time/                   |             |
# |    fps                  | 1154        |
# |    iterations           | 51          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.008303064 |
# |    clip_fraction        | 0.0905      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.426      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.189       |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 0.316       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 252         |
# |    ep_rew_mean          | 71.8        |
# | time/                   |             |
# |    fps                  | 1154        |
# |    iterations           | 52          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.013284199 |
# |    clip_fraction        | 0.083       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.434      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.134       |
# |    n_updates            | 710         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.392       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 254         |
# |    ep_rew_mean          | 72.3        |
# | time/                   |             |
# |    fps                  | 1155        |
# |    iterations           | 53          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.009073359 |
# |    clip_fraction        | 0.0876      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.421      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.171       |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 0.309       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 255         |
# |    ep_rew_mean          | 72.8        |
# | time/                   |             |
# |    fps                  | 1157        |
# |    iterations           | 54          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.011926352 |
# |    clip_fraction        | 0.0846      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.42       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.136       |
# |    n_updates            | 730         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 0.275       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 251         |
# |    ep_rew_mean          | 72.8        |
# | time/                   |             |
# |    fps                  | 1158        |
# |    iterations           | 55          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.010355966 |
# |    clip_fraction        | 0.0849      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.45       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0999      |
# |    n_updates            | 740         |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 0.314       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# ...
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.404       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 236        |
# |    ep_rew_mean          | 71.9       |
# | time/                   |            |
# |    fps                  | 1162       |
# |    iterations           | 81         |
# |    time_elapsed         | 142        |
# |    total_timesteps      | 165888     |
# | train/                  |            |
# |    approx_kl            | 0.01071507 |
# |    clip_fraction        | 0.0938     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.455     |
# |    explained_variance   | 0.995      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.152      |
# |    n_updates            | 1000       |
# |    policy_gradient_loss | -0.0143    |
# |    value_loss           | 0.362      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 235        |
# |    ep_rew_mean          | 71.9       |
# | time/                   |            |
# |    fps                  | 1162       |
# |    iterations           | 82         |
# |    time_elapsed         | 144        |
# |    total_timesteps      | 167936     |
# | train/                  |            |
# |    approx_kl            | 0.01061482 |
# |    clip_fraction        | 0.0968     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.454     |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.139      |
# |    n_updates            | 1010       |
# |    policy_gradient_loss | -0.0128    |
# |    value_loss           | 0.381      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 234         |
# |    ep_rew_mean          | 72.1        |
# | time/                   |             |
# |    fps                  | 1162        |
# |    iterations           | 83          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.010937244 |
# |    clip_fraction        | 0.0953      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.45       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.126       |
# |    n_updates            | 1020        |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 0.362       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 234       |
# |    ep_rew_mean          | 72.2      |
# | time/                   |           |
# |    fps                  | 1163      |
# |    iterations           | 84        |
# |    time_elapsed         | 147       |
# |    total_timesteps      | 172032    |
# | train/                  |           |
# |    approx_kl            | 0.0107844 |
# |    clip_fraction        | 0.106     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.484    |
# |    explained_variance   | 0.996     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.187     |
# |    n_updates            | 1030      |
# |    policy_gradient_loss | -0.0153   |
# |    value_loss           | 0.345     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 233         |
# |    ep_rew_mean          | 72          |
# | time/                   |             |
# |    fps                  | 1163        |
# |    iterations           | 85          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.011688475 |
# |    clip_fraction        | 0.0909      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.417      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.111       |
# |    n_updates            | 1040        |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 0.352       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 235         |
# |    ep_rew_mean          | 72.1        |
# | time/                   |             |
# |    fps                  | 1163        |
# |    iterations           | 86          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.012932639 |
# |    clip_fraction        | 0.0969      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.473      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0809      |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | -0.0187     |
# |    value_loss           | 0.401       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 238          |
# |    ep_rew_mean          | 72.1         |
# | time/                   |              |
# |    fps                  | 1164         |
# |    iterations           | 87           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0110982545 |
# |    clip_fraction        | 0.0873       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.402       |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.135        |
# |    n_updates            | 1060         |
# |    policy_gradient_loss | -0.0155      |
# |    value_loss           | 0.346        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 240          |
# |    ep_rew_mean          | 71.9         |
# | time/                   |              |
# |    fps                  | 1164         |
# |    iterations           | 88           |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0124195535 |
# |    clip_fraction        | 0.098        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.411       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0923       |
# |    n_updates            | 1070         |
# |    policy_gradient_loss | -0.0123      |
# |    value_loss           | 0.302        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 238         |
# |    ep_rew_mean          | 71.6        |
# | time/                   |             |
# |    fps                  | 1164        |
# |    iterations           | 89          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.012887726 |
# |    clip_fraction        | 0.0764      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.415      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.055       |
# |    n_updates            | 1080        |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 0.323       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 238         |
# |    ep_rew_mean          | 71.4        |
# | time/                   |             |
# |    fps                  | 1164        |
# |    iterations           | 90          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.012247836 |
# |    clip_fraction        | 0.0958      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.452      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.163       |
# |    n_updates            | 1090        |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 0.377       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 235         |
# |    ep_rew_mean          | 70.9        |
# | time/                   |             |
# |    fps                  | 1164        |
# |    iterations           | 91          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.011617798 |
# |    clip_fraction        | 0.0908      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.434      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0777      |
# |    n_updates            | 1100        |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.321       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 71.2        |
# | time/                   |             |
# |    fps                  | 1165        |
# |    iterations           | 92          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.010887433 |
# |    clip_fraction        | 0.0963      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.436      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.103       |
# |    n_updates            | 1110        |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 0.301       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 237         |
# |    ep_rew_mean          | 71.2        |
# | time/                   |             |
# |    fps                  | 1165        |
# |    iterations           | 93          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.012908751 |
# |    clip_fraction        | 0.0941      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.401      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.136       |
# |    n_updates            | 1120        |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 0.398       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 71.4        |
# | time/                   |             |
# |    fps                  | 1166        |
# |    iterations           | 94          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.010271094 |
# |    clip_fraction        | 0.0871      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.459      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.267       |
# |    n_updates            | 1130        |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.578       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | 72.2        |
# | time/                   |             |
# |    fps                  | 1166        |
# |    iterations           | 95          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.010822086 |
# |    clip_fraction        | 0.0812      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.399      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.169       |
# |    n_updates            | 1140        |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 0.332       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 244         |
# |    ep_rew_mean          | 72.6        |
# | time/                   |             |
# |    fps                  | 1167        |
# |    iterations           | 96          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.011603006 |
# |    clip_fraction        | 0.0924      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.424      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.169       |
# |    n_updates            | 1150        |
# |    policy_gradient_loss | -0.00856    |
# |    value_loss           | 0.392       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 249         |
# |    ep_rew_mean          | 73.4        |
# | time/                   |             |
# |    fps                  | 1167        |
# |    iterations           | 97          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.015559905 |
# |    clip_fraction        | 0.0992      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.401      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0985      |
# |    n_updates            | 1160        |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 0.437       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 246         |
# |    ep_rew_mean          | 73.6        |
# | time/                   |             |
# |    fps                  | 1168        |
# |    iterations           | 98          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.010107776 |
# |    clip_fraction        | 0.0952      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.398      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.151       |
# |    n_updates            | 1170        |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 0.33        |
# -----------------------------------------

# %% [markdown]
# ### 5. Save model

# %%
#PPO_Path = os.path.join('Training', 'Saved Models', 'Constant_PPO_Model_Discard_Penalty')

# %%
#model.save(PPO_Path)

# %% [markdown]
# ### 6. Load model

# %%
#model = PPO.load(PPO_Path, env=env)

# %% [markdown]
# ### 7. Test model

# %%
MAX_STEPS = 1000
episodes = 10

for episode in range(1, episodes+1):
    obs = env.reset()
    steps = 0
    done = False
    score = 0
    
    while not done and steps < MAX_STEPS:
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score += reward
        steps += 1

    print('Episode:{} Score:{}'.format(episode,score))
    print(env.logs)
    print(getPercentageFilled(env))
    env.logs = { 'placed':0, 'misplaced':0, 'discarded':0 }
# Out:
# Episode:1 Score:-5
# {'placed': 52, 'misplaced': 57, 'discarded': 72}
# Bin 1: 100.0%
# Bin 2: 100.0%
# Bin 3: 100.0%
# Bin 4: 100.0%
# Bin 5: 100.0%
# Bin 6: 100.0%
# Bin 7: 95.0%
# Bin 8: 95.0%
# Bin 9: 100.0%
# Bin 10: 100.0%
# None
# Episode:2 Score:7
# {'placed': 50, 'misplaced': 43, 'discarded': 67}
# Bin 1: 95.0%
# Bin 2: 100.0%
# Bin 3: 95.0%
# Bin 4: 95.0%
# Bin 5: 100.0%
# Bin 6: 100.0%
# Bin 7: 95.0%
# Bin 8: 95.0%
# Bin 9: 100.0%
# Bin 10: 100.0%
# None
# Episode:3 Score:17
# {'placed': 47, 'misplaced': 30, 'discarded': 24}
# Bin 1: 100.0%
# Bin 2: 95.0%
# Bin 3: 100.0%
# Bin 4: 100.0%
# Bin 5: 100.0%
# Bin 6: 100.0%
# Bin 7: 100.0%
# Bin 8: 95.0%
# Bin 9: 100.0%
# Bin 10: 95.0%
# None
# Episode:4 Score:11
# {'placed': 54, 'misplaced': 43, 'discarded': 77}
# Bin 1: 100.0%
# Bin 2: 95.0%
# Bin 3: 100.0%
# Bin 4: 100.0%
# Bin 5: 100.0%
# Bin 6: 95.0%
# Bin 7: 95.0%
# Bin 8: 95.0%
# Bin 9: 100.0%
# Bin 10: 100.0%
# None
# Episode:5 Score:-3
# {'placed': 42, 'misplaced': 45, 'discarded': 67}
# Bin 1: 100.0%
# Bin 2: 100.0%
# Bin 3: 95.0%
# Bin 4: 95.0%
# Bin 5: 100.0%
# Bin 6: 100.0%
# Bin 7: 100.0%
# Bin 8: 100.0%
# Bin 9: 100.0%
# Bin 10: 100.0%
# None
# Episode:6 Score:-6
# {'placed': 50, 'misplaced': 56, 'discarded': 82}
# Bin 1: 100.0%
# Bin 2: 95.0%
# Bin 3: 100.0%
# Bin 4: 95.0%
# Bin 5: 100.0%
# Bin 6: 95.0%
# Bin 7: 100.0%
# Bin 8: 95.0%
# Bin 9: 95.0%
# Bin 10: 100.0%
# None
# Episode:7 Score:4
# {'placed': 41, 'misplaced': 37, 'discarded': 45}
# Bin 1: 95.0%
# Bin 2: 100.0%
# Bin 3: 95.0%
# Bin 4: 100.0%
# Bin 5: 95.0%
# Bin 6: 100.0%
# Bin 7: 95.0%
# Bin 8: 100.0%
# Bin 9: 95.0%
# Bin 10: 100.0%
# None
# Episode:8 Score:7
# {'placed': 48, 'misplaced': 41, 'discarded': 123}
# Bin 1: 100.0%
# Bin 2: 100.0%
# Bin 3: 100.0%
# Bin 4: 100.0%
# Bin 5: 100.0%
# Bin 6: 100.0%
# Bin 7: 95.0%
# Bin 8: 95.0%
# Bin 9: 95.0%
# Bin 10: 100.0%
# None
# Episode:9 Score:7
# {'placed': 47, 'misplaced': 40, 'discarded': 86}
# Bin 1: 100.0%
# Bin 2: 95.0%
# Bin 3: 100.0%
# Bin 4: 95.0%
# Bin 5: 95.0%
# Bin 6: 95.0%
# Bin 7: 100.0%
# Bin 8: 100.0%
# Bin 9: 95.0%
# Bin 10: 95.0%
# None
# Episode:10 Score:-17
# {'placed': 44, 'misplaced': 61, 'discarded': 59}
# Bin 1: 95.0%
# Bin 2: 95.0%
# Bin 3: 95.0%
# Bin 4: 100.0%
# Bin 5: 95.0%
# Bin 6: 100.0%
# Bin 7: 95.0%
# Bin 8: 95.0%
# Bin 9: 95.0%
# Bin 10: 100.0%
# None
